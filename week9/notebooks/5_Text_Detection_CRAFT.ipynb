# %% [markdown]
# # <font color="blue">Text Detection using CRAFT </font>
# In this notebook, we will discuss how to use the CRAFT text detection model. We will use a library called [Keras-ocr](https://github.com/faustomorales/keras-ocr) developed Fausto Morales and other contributors.

# %% [markdown]
# ## <font color="blue">What is Keras-ocr?</font>
# Keras-ocr is a python package for performing OCR. It implements a Text Detection -> Text Recognition pipeline where Text Detection is done using the CRAFT algorithm published in CVPR-2019 and Text Recognition is done using the [CRNN algorithm](https://arxiv.org/abs/1507.05717) which was published in TPAMI-2017.
#
# It is released under the MIT license making it a free software. While there are many text detection papers which provide code and models, it is sometimes difficult to make them work. The good thing about Keras-ocr is that it is also available as a [pypi package](https://pypi.org/project/keras-ocr/) making it easy to install and use.
#
# Moreover, the library has quite a few utility functions which help in OCR related tasks. For example, it has functionality for generating bounding boxes, aligning them, annotating images with bounding boxes and text etc.
#
# We will discuss the Text Detection process in this notebook and Text Recognition in the next notebook.

# %% [markdown]
# # <font color="blue">1. Install Keras-OCR package</font>

# %%
# !pip install keras-ocr
# Out:
# Requirement already satisfied: keras-ocr in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (0.9.3)
# Requirement already satisfied: editdistance in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (0.8.1)
# Requirement already satisfied: efficientnet==1.0.0 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (1.0.0)
# Requirement already satisfied: essential_generators in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (1.0)
# Requirement already satisfied: fonttools in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (4.59.0)
# Requirement already satisfied: imgaug in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (0.4.0)
# Requirement already satisfied: pyclipper in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (1.4.0)
# Requirement already satisfied: shapely in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (2.1.2)
# Requirement already satisfied: tqdm in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (4.67.1)
# Requirement already satisfied: validators in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-ocr) (0.35.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from efficientnet==1.0.0->keras-ocr) (1.0.8)
# Requirement already satisfied: scikit-image in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from efficientnet==1.0.0->keras-ocr) (0.25.2)
# Requirement already satisfied: numpy>=1.9.1 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras-ocr) (2.2.6)
# Requirement already satisfied: h5py in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras-ocr) (3.15.1)
# Requirement already satisfied: six in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from imgaug->keras-ocr) (1.17.0)
# Requirement already satisfied: scipy in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from imgaug->keras-ocr) (1.16.1)
# Requirement already satisfied: Pillow in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from imgaug->keras-ocr) (11.3.0)
# Requirement already satisfied: matplotlib in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from imgaug->keras-ocr) (3.10.5)
# Requirement already satisfied: opencv-python in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from imgaug->keras-ocr) (4.12.0.88)
# Requirement already satisfied: imageio in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from imgaug->keras-ocr) (2.37.2)
# Requirement already satisfied: networkx>=3.0 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (3.6.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (2025.10.16)
# Requirement already satisfied: packaging>=21 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from matplotlib->imgaug->keras-ocr) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from matplotlib->imgaug->keras-ocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from matplotlib->imgaug->keras-ocr) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from matplotlib->imgaug->keras-ocr) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages (from matplotlib->imgaug->keras-ocr) (2.9.0.post0)

# %% [markdown]
# # <font color="blue">2. Import Libraries</font>

# %%
import numpy as np
# Monkey-patch np.sctypes for older libs (imgaug, etc.) on NumPy 2.x
if not hasattr(np, "sctypes"):
    np.sctypes = {
        "float":   [np.float16, np.float32, np.float64],
        "int":     [np.int8, np.int16, np.int32, np.int64],
        "uint":    [np.uint8, np.uint16, np.uint32, np.uint64],
        "complex": [np.complex64, np.complex128],
        # older code sometimes checks this key, it's fine to leave it minimal
        "others":  [np.bool_, np.object_],
    }

# %%
import keras_ocr
import cv2
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # <font color="blue">3. Create a Detector Object</font>
# You can create a detector object using the following function. Check out the [documentation](https://keras-ocr.readthedocs.io/en/latest/api.html#keras_ocr.detection.Detector) if you need more details.

# %%
detector = keras_ocr.detection.Detector()
# Out:
# Looking for /home/gsemonis/.keras-ocr/craft_mlt_25k.h5
# Downloading /home/gsemonis/.keras-ocr/craft_mlt_25k.h5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765658245.161475    3214 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21452 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %% [markdown]
# # <font color="blue">4. Download Images</font>

# %%
# !wget https://www.dropbox.com/s/xz24vxrp4uvvnri/license_plate.jpg?dl=0 -O demo1.jpg --quiet
# !wget https://www.dropbox.com/s/uwlnxiihqgni57o/streetsign1.jpg?dl=0 -O demo2.jpg --quiet
# !wget https://www.dropbox.com/s/dbkag5gsicxqoqg/streetsign2.jpg?dl=0 -O demo3.jpg --quiet

# %% [markdown]
# # <font color="blue">5. Load Images</font>

# %% [markdown]
# Get all images starting with demo and create a list. We will perform detection on this list of images.

# %%
imageNames = glob.glob("demo*.jpg")

# %%
images = [keras_ocr.tools.read(imageName) for imageName in imageNames]

# %% [markdown]
# # <font color="blue">6. Detect Text</font>
# For detection, we need to **`call the detector with a list of images.`**
#
# It returns a list containing the bounding boxes for each image.
#
# Caution: If you want to run on only a single image, you need to put that in a list, otherwise it will throw an error.

# %%
detections = []
for img in images:
    detections.append(detector.detect([img])[0])  # detect expects a list
# Out:
# WARNING:tensorflow:From /home/gsemonis/anaconda3/envs/opencv2/lib/python3.12/site-packages/tensorflow/python/util/dispatch.py:1264: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# 2025-12-13 14:46:11.866708: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f771801a170 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-13 14:46:11.866737: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2025-12-13 14:46:11.891701: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-13 14:46:12.030403: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-12-13 14:46:12.722760: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:12.817669: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:13.138200: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:13.240924: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:13.953073: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 64.65GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-13 14:46:14.043262: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 129.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-13 14:46:14.079532: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 32.59GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-13 14:46:17.553912: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv (f32[1,64,400,600]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,192,400,600]{3,2,1,0}, f32[64,192,1,1]{3,2,1,0}, f32[64]{0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-13 14:46:17.564378: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 2.688177583s
# Trying algorithm eng13{} for conv (f32[1,64,400,600]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,192,400,600]{3,2,1,0}, f32[64,192,1,1]{3,2,1,0}, f32[64]{0}), window={size=1x1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step
# I0000 00:00:1765658778.463030    3403 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-12-13 14:46:19.425785: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:19.561798: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:20.381091: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:20.556937: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:20.941328: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:21.056636: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:21.772629: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:21.927025: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:23.591862: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 129.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-13 14:46:24.039332: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 64.77GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-13 14:46:24.843578: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:24.931777: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.084211: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.172438: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.261431: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.350861: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.439505: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.528377: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.617732: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.706452: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.793829: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:25.881660: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:26.042961: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:26.129472: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# 2025-12-13 14:46:27.824687: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:28.053918: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:28.219393: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:29.454536: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:29.685934: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:30.205991: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:30.345755: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:31.355989: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:31.555607: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:31.793298: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:32.012170: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng13{} for conv (f32[1,128,1000,1500]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,1000,1500]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-13 14:46:32.016869: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:32.072515: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.060426944s
# Trying algorithm eng13{} for conv (f32[1,128,1000,1500]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,1000,1500]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2025-12-13 14:46:34.623638: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 129.28GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-13 14:46:35.391463: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 64.77GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-12-13 14:46:36.822403: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:36.924616: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:37.027172: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:37.221773: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:37.321149: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:37.555199: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:37.655347: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-13 14:46:37.751410: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step

# %% [markdown]
# # <font color="blue">7. Display Annotated Output</font>
# For displaying the annotated bounding boxes, we can use the function **`drawBoxes`**. It takes in the image and detections from the detector and returns an image with the boxes annotated on it.
#
# It uses opencv to draw the boxes under the hood.

# %%
# Plot the predictions
for image, detection in zip(images, detections):
    img = keras_ocr.tools.drawBoxes(image=image, boxes=detection)
    plt.figure(figsize=[10,10])
    plt.imshow(img)
    plt.show()

# %% [markdown]
# # <font color="blue">8. Save cropped and aligned text boxes</font>
# We need to get all cropped text boxes. Then either save it for future use or store it in a variable.
#
# We use the function **`warpBox`** which aligns the bounding box using a perspective transform. You need to pass a single bounding box along with the image and it will return the cropped and aligned text box.

# %%
# create a list to store all boxes for all images
image_boxes_all = []
# Go over all images and detections to create cropped and aligned boxes
for imageName, image, detection in zip(imageNames, images, detections):
  # create a list to store all boxes for an image
  image_boxes = []
  for i,det in enumerate(detection):
    # crop and align(warp) the box
    cropped_warped = keras_ocr.tools.warpBox(image, det)
    image_boxes.append(cropped_warped)
    # save the boxes in separate files
    cv2.imwrite("crop{}_{}".format(i,imageName), cv2.cvtColor(cropped_warped,cv2.COLOR_RGB2BGR))
  # Add all boxes for the particular image to the list
  image_boxes_all.append(image_boxes)

# %% [markdown]
# We will see how to use these text boxes to improve text recognition accuracy of Tesseract as well as how it is used for Text Recognition in the Keras-ocr library in the next few notebooks.
