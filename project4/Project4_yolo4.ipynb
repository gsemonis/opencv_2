# %% [markdown]
# THis notebook is modified from training for yolo 3. many of the early steps are already done, building yolo etc so i will be continuing from the end of the Project4_yolov3 notebook

# %%
# !pwd
# Out:
# /home/gsemonis/opencvCourses/opencv_2/project4

# %%
#change to darknet dir
# %cd darknet
# Out:
# /home/gsemonis/opencvCourses/opencv_2/project4/darknet

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4.conv.137 -O project4/yolov4.conv.137
# Out:
# --2025-11-29 20:41:48--  https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v4_pre/yolov4.conv.137
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
cp ./cfg/yolov4.cfg ./project4/yolov4Masks.cfg

# %%
# !./darknet detector train ./project4/yoloV3_mask.data ./project4/yolov4Masks.cfg ./project4/yolov4.conv.137 -dont_show -map 2> ./project4/train_log_yolo4.txt
# Out:
#  Prepare additional network for mAP calculation...
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
# Create CUDA-stream - 0
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# yolov4Masks
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
# nms_kind: greedynms (1), beta = 0.600000
#
#  seen 64, trained: 0 K-images (0 Kilo-batches_64)
# Weights are saved after: 1000 iterations. Last weights (*_last.weight) are stored every 100 iterations.
# Learning Rate: 0.0013, Momentum: 0.949, Decay: 0.0005
#  Detection layer: 139 - type = 28
#  Detection layer: 150 - type = 28
#  Detection layer: 161 - type = 28
# Loaded: 0.404549 seconds
#
#  (next mAP calculation at 1000 iterations) 1/6000: loss=862.1 hours left=-1.0
# ...

# %%
# !./darknet detector demo ./project4/yoloV3_mask.data ./project4/yolov4Masks.cfg ./project4/backup/yolov4Masks_best.weights ../test-video1.mp4 -thresh .6 -out_filename ../out-vid1Yolo4.avi -dont_show
# Out:
#  CUDA-version: 13000 (13000), GPU count: 1
#  OpenCV version: 4.6.0
# Demo
#  0 : compute_capability = 890, cudnn_half = 0, GPU: NVIDIA GeForce RTX 4090
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %%
# !./darknet detector demo ./project4/yoloV3_mask.data ./project4/yolov4Masks.cfg ./project4/backup/yolov4Masks_best.weights ../test-video2.mp4 -thresh .6 -out_filename ../out-vid2Yolo4.avi -dont_show
# Out:
#  CUDA-version: 13000 (13000), GPU count: 1
#  OpenCV version: 4.6.0
# Demo
#  0 : compute_capability = 890, cudnn_half = 0, GPU: NVIDIA GeForce RTX 4090
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...
